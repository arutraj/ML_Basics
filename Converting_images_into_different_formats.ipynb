# %% [markdown]
# <a href="https://colab.research.google.com/github/arutraj/ML_Basics/blob/main/Converting_images_into_different_formats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading Required Libraries

# %%
# importing modules from skimage to read and display images
from skimage.io import imshow, imread, imsave
from skimage.color import rgb2gray, rgba2rgb
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Loading a RGB image

# %%
# reading the image using its path
image = imread('/content/drive/MyDrive/AnalyticsVidya/dog.jpg')

# %%
#checking shape of image
image.shape
# Out:
# (340, 453, 3)

# %%
# plotting the image
imshow(image)

# %% [markdown]
# ## Loading RGBA image

# %%
image_rgba = imread('/content/drive/MyDrive/AnalyticsVidya/mid_alpha.png')
image_rgba.shape
# Out:
# (340, 453, 4)

# %%
imshow(image_rgba)

# %% [markdown]
# ## Converting RGBA to RGB

# %%
image_rgba = imread('/content/drive/MyDrive/AnalyticsVidya/mid_alpha.png')
image_rgba.shape
# Out:
# (340, 453, 4)

# %%
# converting rgba to rgb
image_rgb = rgba2rgb(image_rgba)
image_rgb.shape
# Out:
# (340, 453, 3)

# %%
imshow(image_rgb)

# %% [markdown]
# ## Converting RGB to grayscale image

# %%
# converting rgb to gray
image_gray = rgb2gray(image)
image_gray.shape
# Out:
# (340, 453)

# %%
imshow(image_gray)

# %% [markdown]
# ## Challenge #2 - Loading RGB in Grayscale format

# %%
image_ = imread('/content/drive/MyDrive/AnalyticsVidya/dog.jpg', as_gray=True)
imshow(image_)

# %%
image_ = imread('/content/drive/MyDrive/AnalyticsVidya/mid_alpha.png', as_gray=True)
print(image_.shape)
imshow(image_)
# Out:
# (340, 453)
