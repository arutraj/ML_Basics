# %% [markdown]
# <a href="https://colab.research.google.com/github/arutraj/ML_Basics/blob/main/PythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy

# %%
np.__version__
# Out:
# '1.25.2'

# %%
#!pip3 install scipy==1.11.4  with the versio specified
scipy.__version__
# Out:
# '1.11.4'

# %%
from scipy.misc import derivative

# %%
def my_func(x):
  return x**2 + 5

# %%
# calculate the first derivative of the function at x=2
derivative(func = my_func, x0=2)
# Out:
# <ipython-input-18-f61121c9d29d>:2: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   derivative(func = my_func, x0=2)
# 4.0

# %%
derivative(func = my_func, x0=2,n=2)
# Out:
# <ipython-input-10-387a7499f43d>:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   derivative(func = my_func, x0=2,n=2)
# 2.0

# %%
from scipy.special import comb  ## COMBINATIONS
#4C2
com = comb(4,2)
com
# Out:
# 6.0

# %%
from scipy.special import perm  ## PERMUTATIONS
#4P2
per = perm(4,2)
print(per)
# Out:
# 12.0

# %%
from scipy import linalg
# square matrix
matrix  = np.array([[1,4,3],
                   [8,7,2],
                   [2,4,2]])

# %%
matrix
# Out:
# array([[1, 4, 3],
#        [8, 7, 2],
#        [2, 4, 2]])

# %%
linalg.det(matrix)  # pass values to det() function
# Out:
# 12.0

# %%
linalg.inv(matrix)  # inverse of a matrix
# Out:
# array([[ 0.5       ,  0.33333333, -1.08333333],
#        [-1.        , -0.33333333,  1.83333333],
#        [ 1.5       ,  0.33333333, -2.08333333]])

# %%
import pandas as pd
import os
import gdown
import zipfile

# %%
# !pip install zipfile
# Out:
# ERROR: Could not find a version that satisfies the requirement zipfile (from versions: none)
# ERROR: No matching distribution found for zipfile

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
zip_url = "https://drive.google.com/uc?export=download&id=1KrnpfYRKVxGDnj-R2VZmNscEkR1zr2-4"

dataset_path = os.path.join("./dataset", "donors_choose")
zip_file_path = os.path.join(dataset_path, "donors_choose_dataset.zip")

if not os.path.exists(dataset_path):
  os.makedirs(dataset_path)

if not os.path.exists(zip_file_path):
   gdown.download(zip_url, zip_file_path, quiet=False)

with zipfile.ZipFile(zip_file_path ,"r") as zip_ref:
    zip_ref.extractall(dataset_path)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1KrnpfYRKVxGDnj-R2VZmNscEkR1zr2-4
# From (redirected): https://drive.google.com/uc?export=download&id=1KrnpfYRKVxGDnj-R2VZmNscEkR1zr2-4&confirm=t&uuid=c8ea150d-9a04-4fe9-96da-716462b06226
# To: /content/dataset/donors_choose/donors_choose_dataset.zip
# 100%|██████████| 111M/111M [00:04<00:00, 26.4MB/s]

# %%
# read the file
dc_resources = pd.read_csv('/content/dataset/donors_choose/resources.csv')
dc_train_data = pd.read_csv('/content/dataset/donors_choose/train_data.csv')

# %%
#view the data
dc_resources.head(3)
# Out:
#         id                                        description  quantity  \
# 0  p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1  p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2  p069063  Cory Stories: A Kid's Book About Living With Adhd         1
#
#     price
# 0  149.00
# 1   14.95
# 2    8.45

# %%
dc_resources.shape
# Out:
# (1541272, 4)

# %%
dc_resources.columns
# Out:
# Index(['id', 'description', 'quantity', 'price'], dtype='object')

# %%
# view the data
dc_train_data.head(3)
# Out:
#    Unnamed: 0       id                        teacher_id teacher_prefix  \
# 0      160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.
# 1      140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.
# 2       21895  p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.
#
#   school_state project_submitted_datetime project_grade_category  \
# 0           IN        2016-12-05 13:43:57          Grades PreK-2
# 1           FL        2016-10-25 09:22:10             Grades 6-8
# 2           AZ        2016-08-31 12:03:56             Grades 6-8
#
#           project_subject_categories     project_subject_subcategories  \
# 0                Literacy & Language                     ESL, Literacy
# 1  History & Civics, Health & Sports  Civics & Government, Team Sports
# 2                    Health & Sports    Health & Wellness, Team Sports
#
#                                        project_title  \
# 0   Educational Support for English Learners at Home
# 1              Wanted: Projector for Hungry Learners
# 2  Soccer Equipment for AWESOME Middle School Stu...
#
#                                      project_essay_1  \
# 0  My students are English learners that are work...
# 1  Our students arrive to our school eager to lea...
# 2  \r\n\"True champions aren't always the ones th...
#
#                                      project_essay_2 project_essay_3  \
# 0  \"The limits of your language are the limits o...             NaN
# 1  The projector we need for our school is very c...             NaN
# 2  The students on the campus come to school know...             NaN
#
#   project_essay_4                           project_resource_summary  \
# 0             NaN  My students need opportunities to practice beg...
# 1             NaN  My students need a projector to help with view...
# 2             NaN  My students need shine guards, athletic socks,...
#
#    teacher_number_of_previously_posted_projects  project_is_approved
# 0                                             0                    0
# 1                                             7                    1
# 2                                             1                    0

# %%
# check the column names
dc_train_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'teacher_id', 'teacher_prefix', 'school_state',
#        'project_submitted_datetime', 'project_grade_category',
#        'project_subject_categories', 'project_subject_subcategories',
#        'project_title', 'project_essay_1', 'project_essay_2',
#        'project_essay_3', 'project_essay_4', 'project_resource_summary',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved'],
#       dtype='object')

# %%
# shape of the data
dc_train_data.shape
# Out:
# (109248, 17)

# %%
#check the datatypes in the column
# object is string
dc_train_data.dtypes
# Out:
# Unnamed: 0                                       int64
# id                                              object
# teacher_id                                      object
# teacher_prefix                                  object
# school_state                                    object
# project_submitted_datetime                      object
# project_grade_category                          object
# project_subject_categories                      object
# project_subject_subcategories                   object
# project_title                                   object
# project_essay_1                                 object
# project_essay_2                                 object
# project_essay_3                                 object
# project_essay_4                                 object
# project_resource_summary                        object
# teacher_number_of_previously_posted_projects     int64
# project_is_approved                              int64
# dtype: object

# %%
#check the null values in the data
#dc_train_data.isna().sum()
dc_train_data.isnull().sum()
# Out:
# Unnamed: 0                                           0
# id                                                   0
# teacher_id                                           0
# teacher_prefix                                       3
# school_state                                         0
# project_submitted_datetime                           0
# project_grade_category                               0
# project_subject_categories                           0
# project_subject_subcategories                        0
# project_title                                        0
# project_essay_1                                      0
# project_essay_2                                      0
# project_essay_3                                 105490
# project_essay_4                                 105490
# project_resource_summary                             0
# teacher_number_of_previously_posted_projects         0
# project_is_approved                                  0
# dtype: int64

# %%
# summary of the data
dc_train_data.describe()
# Out:
#           Unnamed: 0  teacher_number_of_previously_posted_projects  \
# count  109248.000000                                 109248.000000
# mean    91183.786568                                     11.153165
# std     52548.095272                                     27.777154
# min         0.000000                                      0.000000
# 25%     45743.500000                                      0.000000
# 50%     91253.500000                                      2.000000
# 75%    136712.500000                                      9.000000
# max    182079.000000                                    451.000000
#
#        project_is_approved
# count        109248.000000
# mean              0.848583
# std               0.358456
# min               0.000000
# 25%               1.000000
# 50%               1.000000
# 75%               1.000000
# max               1.000000

# %%
dc_train_data.loc[dc_train_data.teacher_prefix.isna() ==True]
# Out:
#        Unnamed: 0       id                        teacher_id teacher_prefix  \
# 7820        17809  p180947  834f75f1b5e24bd10abe9c3dbf7ba12f            NaN
# 30368       22174  p002730  339bd5a9e445d68a74d65b99cd325397            NaN
# 57654      158692  p197901  e4be6aaaa887d4202df2b647fbfc82bb            NaN
#
#       school_state project_submitted_datetime project_grade_category  \
# 7820            CA        2016-11-04 00:15:45             Grades 3-5
# 30368           SC        2016-05-09 09:38:40            Grades 9-12
# 57654           PA        2016-06-03 10:15:05             Grades 3-5
#
#                 project_subject_categories      project_subject_subcategories  \
# 7820   Literacy & Language, Math & Science  Literature & Writing, Mathematics
# 30368                  Literacy & Language               Literature & Writing
# 57654  Literacy & Language, Math & Science              Literacy, Mathematics
#
#                                           project_title  \
# 7820   1:7 Increasing Tech to Decrease Achievement Gaps
# 30368                           iPads for STEM Stations
# 57654                                   Document Camera
#
#                                          project_essay_1  \
# 7820   The children at Anna Yates Elementary school a...
# 30368  Within the next 20 years, every job will invol...
# 57654  Students at Robertsdale Elementary live in a l...
#
#                                          project_essay_2  \
# 7820   My goal is to bring in 1 laptop for every 7 st...
# 30368  The students in our school come from a wide va...
# 57654  This SMART Document Camera will improve my stu...
#
#                                          project_essay_3  \
# 7820                                                 NaN
# 30368  Students will use the iPad station for individ...
# 57654                                                NaN
#
#                                          project_essay_4  \
# 7820                                                 NaN
# 30368  Your generosity will allow my students to work...
# 57654                                                NaN
#
#                                 project_resource_summary  \
# 7820   My students need a classroom laptop that is ju...
# 30368        My students need 5 iPads for STEM stations.
# 57654  My students need a Smart Document Camera to en...
#
#        teacher_number_of_previously_posted_projects  project_is_approved
# 7820                                              1                    1
# 30368                                             0                    1
# 57654                                             0                    1

# %%
dc_train_data.loc[dc_train_data.project_essay_3.isna() ==True]
# Out:
#         Unnamed: 0       id                        teacher_id teacher_prefix  \
# 0           160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.
# 1           140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.
# 2            21895  p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.
# 3               45  p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.
# 4           172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.
# ...            ...      ...                               ...            ...
# 109243       38267  p048540  fadf72d6cd83ce6074f9be78a6fcd374            Mr.
# 109244      169142  p166281  1984d915cc8b91aa16b4d1e6e39296c6            Ms.
# 109245      143653  p155633  cdbfd04aa041dc6739e9e576b1fb1478           Mrs.
# 109246      164599  p206114  6d5675dbfafa1371f0e2f6f1b716fe2d           Mrs.
# 109247      128381  p191189  ca25d5573f2bd2660f7850a886395927            Ms.
#
#        school_state project_submitted_datetime project_grade_category  \
# 0                IN        2016-12-05 13:43:57          Grades PreK-2
# 1                FL        2016-10-25 09:22:10             Grades 6-8
# 2                AZ        2016-08-31 12:03:56             Grades 6-8
# 3                KY        2016-10-06 21:16:17          Grades PreK-2
# 4                TX        2016-07-11 01:10:09          Grades PreK-2
# ...             ...                        ...                    ...
# 109243           MO        2016-06-17 12:02:31          Grades PreK-2
# 109244           NJ        2017-01-11 12:49:39          Grades PreK-2
# 109245           NJ        2016-08-25 17:11:32          Grades PreK-2
# 109246           NY        2016-07-29 17:53:15             Grades 3-5
# 109247           VA        2016-06-29 09:17:01             Grades 6-8
#
#                  project_subject_categories  \
# 0                       Literacy & Language
# 1         History & Civics, Health & Sports
# 2                           Health & Sports
# 3       Literacy & Language, Math & Science
# 4                            Math & Science
# ...                                     ...
# 109243  Literacy & Language, Math & Science
# 109244  Literacy & Language, Math & Science
# 109245  Literacy & Language, Math & Science
# 109246       Health & Sports, Special Needs
# 109247     Applied Learning, Math & Science
#
#              project_subject_subcategories  \
# 0                            ESL, Literacy
# 1         Civics & Government, Team Sports
# 2           Health & Wellness, Team Sports
# 3                    Literacy, Mathematics
# 4                              Mathematics
# ...                                    ...
# 109243   Literature & Writing, Mathematics
# 109244               Literacy, Mathematics
# 109245               Literacy, Mathematics
# 109246    Health & Wellness, Special Needs
# 109247  College & Career Prep, Mathematics
#
#                                             project_title  \
# 0        Educational Support for English Learners at Home
# 1                   Wanted: Projector for Hungry Learners
# 2       Soccer Equipment for AWESOME Middle School Stu...
# 3                                  Techie Kindergarteners
# 4                                  Interactive Math Tools
# ...                                                   ...
# 109243  Privacy Shields Help Promote Independent Thinking
# 109244                        Technology in Our Classroom
# 109245             2016/2017 Beginning of the Year Basics
# 109246            Flexible Seating in Inclusive Classroom
# 109247     Classroom Tech to Develop 21st Century Leaders
#
#                                           project_essay_1  \
# 0       My students are English learners that are work...
# 1       Our students arrive to our school eager to lea...
# 2       \r\n\"True champions aren't always the ones th...
# 3       I work at a unique school filled with both ESL...
# 4       Our second grade classroom next year will be m...
# ...                                                   ...
# 109243  Welcome to Mr. Ramos's 2nd grade classroom! We...
# 109244  Every morning, we start our day with our core ...
# 109245  This is a great group of sharing and caring st...
# 109246  Our students live in a small rural community. ...
# 109247  When was the last time that you used math? Pro...
#
#                                           project_essay_2 project_essay_3  \
# 0       \"The limits of your language are the limits o...             NaN
# 1       The projector we need for our school is very c...             NaN
# 2       The students on the campus come to school know...             NaN
# 3       My students live in high poverty conditions wi...             NaN
# 4       For many students, math is a subject that does...             NaN
# ...                                                   ...             ...
# 109243  I would like to start preparing my second grad...             NaN
# 109244  In this technological age, we need to give our...             NaN
# 109245  My students learn about special events, holida...             NaN
# 109246  Flexible classroom seating has been researched...             NaN
# 109247  According to Forbes Magazine (2014), companies...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 0                  NaN  My students need opportunities to practice beg...
# 1                  NaN  My students need a projector to help with view...
# 2                  NaN  My students need shine guards, athletic socks,...
# 3                  NaN  My students need to engage in Reading and Math...
# 4                  NaN  My students need hands on practice in mathemat...
# ...                ...                                                ...
# 109243             NaN  My students need these privacy partitions to h...
# 109244             NaN  My students need two iPad's and protective cas...
# 109245             NaN  My students need giant comfy pillows in order ...
# 109246             NaN  My students need flexible seating options: bea...
# 109247             NaN  My students need opportunities to work with te...
#
#         teacher_number_of_previously_posted_projects  project_is_approved
# 0                                                  0                    0
# 1                                                  7                    1
# 2                                                  1                    0
# 3                                                  4                    1
# 4                                                  1                    1
# ...                                              ...                  ...
# 109243                                             0                    1
# 109244                                             0                    1
# 109245                                             3                    1
# 109246                                             0                    1
# 109247                                             0                    1
#
# [105490 rows x 17 columns]

# %%
dc_train_data.loc[dc_train_data.project_essay_4.isna() ==True]
# Out:
#         Unnamed: 0       id                        teacher_id teacher_prefix  \
# 0           160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.
# 1           140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.
# 2            21895  p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.
# 3               45  p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.
# 4           172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.
# ...            ...      ...                               ...            ...
# 109243       38267  p048540  fadf72d6cd83ce6074f9be78a6fcd374            Mr.
# 109244      169142  p166281  1984d915cc8b91aa16b4d1e6e39296c6            Ms.
# 109245      143653  p155633  cdbfd04aa041dc6739e9e576b1fb1478           Mrs.
# 109246      164599  p206114  6d5675dbfafa1371f0e2f6f1b716fe2d           Mrs.
# 109247      128381  p191189  ca25d5573f2bd2660f7850a886395927            Ms.
#
#        school_state project_submitted_datetime project_grade_category  \
# 0                IN        2016-12-05 13:43:57          Grades PreK-2
# 1                FL        2016-10-25 09:22:10             Grades 6-8
# 2                AZ        2016-08-31 12:03:56             Grades 6-8
# 3                KY        2016-10-06 21:16:17          Grades PreK-2
# 4                TX        2016-07-11 01:10:09          Grades PreK-2
# ...             ...                        ...                    ...
# 109243           MO        2016-06-17 12:02:31          Grades PreK-2
# 109244           NJ        2017-01-11 12:49:39          Grades PreK-2
# 109245           NJ        2016-08-25 17:11:32          Grades PreK-2
# 109246           NY        2016-07-29 17:53:15             Grades 3-5
# 109247           VA        2016-06-29 09:17:01             Grades 6-8
#
#                  project_subject_categories  \
# 0                       Literacy & Language
# 1         History & Civics, Health & Sports
# 2                           Health & Sports
# 3       Literacy & Language, Math & Science
# 4                            Math & Science
# ...                                     ...
# 109243  Literacy & Language, Math & Science
# 109244  Literacy & Language, Math & Science
# 109245  Literacy & Language, Math & Science
# 109246       Health & Sports, Special Needs
# 109247     Applied Learning, Math & Science
#
#              project_subject_subcategories  \
# 0                            ESL, Literacy
# 1         Civics & Government, Team Sports
# 2           Health & Wellness, Team Sports
# 3                    Literacy, Mathematics
# 4                              Mathematics
# ...                                    ...
# 109243   Literature & Writing, Mathematics
# 109244               Literacy, Mathematics
# 109245               Literacy, Mathematics
# 109246    Health & Wellness, Special Needs
# 109247  College & Career Prep, Mathematics
#
#                                             project_title  \
# 0        Educational Support for English Learners at Home
# 1                   Wanted: Projector for Hungry Learners
# 2       Soccer Equipment for AWESOME Middle School Stu...
# 3                                  Techie Kindergarteners
# 4                                  Interactive Math Tools
# ...                                                   ...
# 109243  Privacy Shields Help Promote Independent Thinking
# 109244                        Technology in Our Classroom
# 109245             2016/2017 Beginning of the Year Basics
# 109246            Flexible Seating in Inclusive Classroom
# 109247     Classroom Tech to Develop 21st Century Leaders
#
#                                           project_essay_1  \
# 0       My students are English learners that are work...
# 1       Our students arrive to our school eager to lea...
# 2       \r\n\"True champions aren't always the ones th...
# 3       I work at a unique school filled with both ESL...
# 4       Our second grade classroom next year will be m...
# ...                                                   ...
# 109243  Welcome to Mr. Ramos's 2nd grade classroom! We...
# 109244  Every morning, we start our day with our core ...
# 109245  This is a great group of sharing and caring st...
# 109246  Our students live in a small rural community. ...
# 109247  When was the last time that you used math? Pro...
#
#                                           project_essay_2 project_essay_3  \
# 0       \"The limits of your language are the limits o...             NaN
# 1       The projector we need for our school is very c...             NaN
# 2       The students on the campus come to school know...             NaN
# 3       My students live in high poverty conditions wi...             NaN
# 4       For many students, math is a subject that does...             NaN
# ...                                                   ...             ...
# 109243  I would like to start preparing my second grad...             NaN
# 109244  In this technological age, we need to give our...             NaN
# 109245  My students learn about special events, holida...             NaN
# 109246  Flexible classroom seating has been researched...             NaN
# 109247  According to Forbes Magazine (2014), companies...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 0                  NaN  My students need opportunities to practice beg...
# 1                  NaN  My students need a projector to help with view...
# 2                  NaN  My students need shine guards, athletic socks,...
# 3                  NaN  My students need to engage in Reading and Math...
# 4                  NaN  My students need hands on practice in mathemat...
# ...                ...                                                ...
# 109243             NaN  My students need these privacy partitions to h...
# 109244             NaN  My students need two iPad's and protective cas...
# 109245             NaN  My students need giant comfy pillows in order ...
# 109246             NaN  My students need flexible seating options: bea...
# 109247             NaN  My students need opportunities to work with te...
#
#         teacher_number_of_previously_posted_projects  project_is_approved
# 0                                                  0                    0
# 1                                                  7                    1
# 2                                                  1                    0
# 3                                                  4                    1
# 4                                                  1                    1
# ...                                              ...                  ...
# 109243                                             0                    1
# 109244                                             0                    1
# 109245                                             3                    1
# 109246                                             0                    1
# 109247                                             0                    1
#
# [105490 rows x 17 columns]

# %%
dc_train_data.loc[dc_train_data.project_essay_3.isna() !=True ,'project_essay_3' ]
# Out:
# 61        These young engineers will use the Magformers ...
# 92        As the School Behavior Health Specialist, I wo...
# 93        Students will use these stands EVERY DAY in a ...
# 159       My robotics club is an after school extension ...
# 163       A PA system will permit me to amplify my voice...
#                                 ...
# 109155    The most important activities that 2nd grade s...
# 109169    I plan on having my students help me create ou...
# 109185    The students will use the pedometers almost da...
# 109213    This resource will allow me to have the abilit...
# 109237    \"Some things you just can't explain. You don'...
# Name: project_essay_3, Length: 3758, dtype: object

# %%
dc_train_data.project_essay_3.mode()
# Out:
# 0    Daily, students will check out their chrome bo...
# 1    I love to make learning fun for my students, h...
# 2    My students need to learn how to rhyme, identi...
# Name: project_essay_3, dtype: object

# %%
dc_train_data.project_essay_3.value_counts()
# Out:
# project_essay_3
# Daily, students will check out their chrome books to fulfill our 1:1 initiative, taking the device to each class where they will learn research methods, note-taking strategies, and use free applications that they can also access on their devices at home.  Living in a world of technology, students grasp electronic concepts more comfortably than the written.  By obtaining the technology to train our students, we can ensure that we are motivating their learning through the means they work with everyday in their diverse home environments.                                                                                                                                                                                                                                                                                                                                                                                                                                                                      2
# I love to make learning fun for my students, however it can be difficult with the lack of resources we have.  My students often get bored with the stories I read because they are not coming to life! My students need storytelling puppets and kits to help them make their story time come to life.  With these storytelling kits my students can have an interactive story time.  It will help them retain information they have learned and inspire a love for learning! My students will also be able to recreate the story on their own in their centers, which will help them develop story telling skills and learn the parts of a story.  Donations to this literacy project will improve my students’ literacy centers and my students recall ability.  My students are eager to learn and just need the materials in order to succeed!                                                                                                                                                                                2
# My students need to learn how to rhyme, identify words with the same beginning sounds, build CVC words, listen to themselves read, and take part in engaging activities while doing so. The activities and materials I am asking for will allow my students to have a richer experience grappling with these concepts that they must master before moving on to first grade.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      2
# My students will use the materials requested for their reading block. I would like each student to have a binder to keep their daily work in. Students will also keep completed work in their file cases. These materials will encourage students to keep their work organized. It will be a skill they will use for the rest of their lives.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# As mentioned before, my students and many others with any kind of deficit cognitive or physical functioning have needs that are not typical. These needs have to do with sensory processing (bright or dim lights, loud or soft sounds, too much or too little pressure, oral-motor sensitivity, smells that are too much or not enough, and so on). When a child with a sensory processing disorder gets over-stimulated, they need tools in place that the teachers can reach for to calm them. We are asking for approved tools. For example, weighted lap blankets are designed to apply pressure that is soothing to a child with sensory issues. They work great but can be expensive. We need many of them.  This type of disorder can be quite scary, and these tools are necessary to help a child focus and engage in their schoolwork because a child's hyper or hyposensitivity is calmed and they can concentrate.\r\n                                                                                               1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ..
# I will use these materials with individual and small groups of students who are not responding to interventions in the general classroom. I will also make them available to the classroom teachers to use as supplement to their community building activities. By focusing on establishing a safe, secure, and nurturing environment, we are teaching children how to learn, and setting the stage for a love of school and the life skill of learning. The Auto Be Good DVD series uses fun animation (Similar to the Cars movies) which students love. The stories are engaging and the teacher guides provide supplemental activities that are an efficient and effective use of teacher time. This gives us more time to make personal connections and build individual relationships with our kids. Some of my students  come from very unstable homes. School may be the only place where they can count on being treated with love and respect everyday.  School may be the only place where emotional needs are met.    1
# With the books, I am asking for to use in my classroom, my students will complete literature circles with them.  They will work on their reading abilities, reading aloud, reading jobs as well as preparing a project for a gallery walk from other teachers and staff members in the building.  During this gallery walk teachers, administrators and other students will critique and give suggestions and positive feedback to the students on the projects.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# We will use these valuable materials in so many ways!\r\n\r\nThe iPads will allow students to be exposed to advanced technology. These iPads allow students to present their learning in a variety of ways through different project showcases. Many apps also assist in personalizing a child's learning so that their instructional needs can be met in a variety of ways.\r\n\r\nThe carpet will provide a comfortable place for students to sit and work outside of the traditional desk/workspace. Alternative seating is a great way for children to have a sense of freedom and especially for those with a few extra wiggles to get out ;).                                                                                                                                                                                                                                                                                                                                                                               1
# By using the whiteboards and dry erase markers, my students will be able to have the advantage of writing their answers for me to see. I can quickly analyze my students answers and check their understanding on the current material being taught. They will learn to be confident in answering questions in the classroom.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# \"Some things you just can't explain. You don't even try. You don't know where to start. All your sentences would jumble up like a giant knot if you opened your mouth. Any words you used would come out wrong.”\r\n\r\nThis is exactly how I feel as I sit here trying to come up with the words to explain this book and how it made me feel.\r\n\r\nChildren can be cruel. Children can be surprisingly empathetic. That’s a part of what this book is about. \r\n\r\nAuggie Pullman was born with a one in a million(s) facial defect. The kind of defect that startles the unsuspecting, the kind of defect that will stop a person dead in their tracks, and at 10 years of age Auggie decides to go to a real school. \r\n\r\nWhenever a new book makes its way into our classroom library, they get excited. A class set of books is not only going to improve my instruction, but it is going to draw them closer together, with one another, as they make connections to the stories.                                  1
# Name: count, Length: 3755, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
matplotlib.__version__
# Out:
# '3.7.1'

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.13.1'

# %%
dctd=sns.load_dataset("dc_train_data")

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.2.2'

# %%
from sklearn.impute import SimpleImputer

# %%
import statsmodels

# %%
statsmodels.__version__
# Out:
# '0.14.2'
